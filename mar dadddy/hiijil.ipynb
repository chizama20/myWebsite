# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB 2.0 MB/s eta 0:00:06
#     --------------------------------------- 0.2/11.5 MB 2.5 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/11.5 MB 2.7 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/11.5 MB 2.9 MB/s eta 0:00:04
#    -- ------------------------------------- 0.7/11.5 MB 3.0 MB/s eta 0:00:04
#    -- ------------------------------------- 0.8/11.5 MB 2.9 MB/s eta 0:00:04
#    --- ------------------------------------ 0.9/11.5 MB 3.0 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/11.5 MB 2.9 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.2/11.5 MB 2.9 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/11.5 MB 3.0 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.5/11.5 MB 3.0 MB/s eta 0:00:04
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv("NBA_list_new.csv")

# %%
data
# Out:
#               PLAYER TEAM  AGE  HEIGHT  WEIGHT                 COLLEGE  \
# 0       Aaron Gordon  ORL   23      81     220                 Arizona
# 1      Aaron Holiday  IND   22      73     185  California-Los Angeles
# 2        Abdel Nader  OKC   25      78     225              Iowa State
# 3         Al Horford  BOS   33      82     245                 Florida
# 4    Al-Farouq Aminu  POR   28      81     220             Wake Forest
# ..               ...  ...  ...     ...     ...                     ...
# 525      Zach LaVine  CHI   24      77     200  California-Los Angeles
# 526      Zach Lofton  DET   26      76     180        New Mexico State
# 527    Zaza Pachulia  DET   35      83     270                     NaN
# 528     Zhaire Smith  PHI   20      76     199              Texas Tech
# 529          Zhou Qi  HOU   23      85     210                     NaN
#
#                 COUNTRY DRAFT YEAR DRAFT ROUND DRAFT NUMBER  ...   PTS  REB  \
# ...
